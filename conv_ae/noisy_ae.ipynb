# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import utils
# %matplotlib inline

# %%
train_loader = utils.loader(train=True, normalize=True)
test_loader = utils.loader(train=False, normalize=True)

# %%
class Net(nn.Module):
    def __init__(self, noise_type='none'):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 64)
        self.fc2 = nn.Linear(64, 28*28)
        self._loss = F.mse_loss
        
        self.noise_type=noise_type
        
    def forward(self, x):
        if self.noise_type == 'normal':
            noise = torch.normal(means=torch.zeros_like(x))
            x.data.add_(noise.data)
        elif self.noise_type == 'drop':
            for i in range(x.shape[0]):
                if i % 2:
                    x[i, :, :, :14] = 0.0
                else:
                    x[i, :, :, 14:] = 0.0
        
        self.x_flatten = x.view(-1, 28*28)
        self.h = F.sigmoid(self.fc1(self.x_flatten))
        self.out = F.tanh(self.fc2(self.h))
        return self.out
    
    def decode(self, x):
        return F.tanh(self.fc2(x))
    
    def loss(self, x, target, **kwargs):
        return self._loss(x, target, **kwargs)

# %%
model = Net(noise_type='normal')
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
def train(epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data = Variable(data)
        target = data.clone()
        
        optimizer.zero_grad()
        output = model(data)
        loss = model.loss(output, target.view(-1, 784))
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data[0]))
    else:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.data[0]))

# %%
def test(log=None):
    test_loss = 0
    for data, target in test_loader:
        data = Variable(data, volatile=True)
        target = target = data.clone()
        
        output = model(data)
        test_loss += model.loss(output, target.view(-1, 784), size_average=False).data[0] # sum up batch loss
    test_loss /= len(test_loader.dataset) * 784
    
    train_loss = 0
    for data, target in train_loader:
        data = Variable(data, volatile=True)
        target = data.clone()
        
        output = model(data)
        train_loss += model.loss(output, target.view(-1, 784), size_average=False).data[0] # sum up batch loss
    train_loss /= len(train_loader.dataset) * 784
    
    print('Average test/train loss: {:.4f}/{:.4f}\n'.format(test_loss, train_loss))
    
    log['test'].append(test_loss)
    log['train'].append(train_loss)

# %%
err_log = {'test': [], 'train': []}

# %%
for epoch in range(1, 11):
    train(epoch)
    test(err_log)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.130168
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 0.508659
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 0.498403
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 0.467134
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.474535
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 0.461455
# Train Epoch: 1 [59950/60000 (100%)]	Loss: 0.495271
# Average test/train loss: 0.4925/0.4884
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.479013
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.463624
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.454873
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.475651
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.488595
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.479498
# Train Epoch: 2 [59950/60000 (100%)]	Loss: 0.520830
# Average test/train loss: 0.4881/0.4837
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.467984
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.489153
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.504789
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.461497
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.495908
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.468017
# Train Epoch: 3 [59950/60000 (100%)]	Loss: 0.500930
# Average test/train loss: 0.4832/0.4792
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.464022
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.454774
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.468824
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.515095
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.473626
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.453600
# Train Epoch: 4 [59950/60000 (100%)]	Loss: 0.495229
# Average test/train loss: 0.4817/0.4772
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.463180
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.506999
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.467004
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.464572
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.435270
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.483114
# Train Epoch: 5 [59950/60000 (100%)]	Loss: 0.484681
# Average test/train loss: 0.4806/0.4762
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.457248
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 0.451290
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 0.473833
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 0.481266
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 0.475667
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 0.454308
# Train Epoch: 6 [59950/60000 (100%)]	Loss: 0.454143
# Average test/train loss: 0.4800/0.4752
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.449819
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 0.463399
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 0.493772
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 0.499111
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 0.491649
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 0.454397
# Train Epoch: 7 [59950/60000 (100%)]	Loss: 0.451071
# Average test/train loss: 0.4797/0.4752
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.491334
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 0.480517
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 0.485314
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 0.477331
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 0.474552
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 0.458973
# Train Epoch: 8 [59950/60000 (100%)]	Loss: 0.484833
# Average test/train loss: 0.4790/0.4745
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.468395
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 0.515390
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 0.484330
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 0.447730
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 0.477443
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 0.478372
# Train Epoch: 9 [59950/60000 (100%)]	Loss: 0.467742
# Average test/train loss: 0.4771/0.4726
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.526930
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 0.470432
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 0.497223
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 0.475252
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 0.476435
# Train Epoch: 10 [50000/60000 (83%)]	Loss: 0.450348
# Train Epoch: 10 [59950/60000 (100%)]	Loss: 0.480046
# Average test/train loss: 0.4770/0.4723

# %%
data, target = next(iter(train_loader))
data = Variable(data, volatile=True)
target = data.clone()

# %%
output = model(data)
to_plot = ((output.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(data.data.numpy(), (10, 5))
utils.plot_mnist(to_plot, (10, 5))
utils.plot_mnist(target.data.numpy(), (10, 5))

# %%
decoded = model.decode(Variable(torch.eye(64)))
dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(dec_to_plot, (8, 8))
