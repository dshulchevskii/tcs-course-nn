# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import utils
# %matplotlib inline

# %%
train_loader = utils.loader(train=True, normalize=True)
test_loader = utils.loader(train=False, normalize=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 64)
        self.fc2 = nn.Linear(64, 28*28)
        self._loss = F.mse_loss
        
    def forward(self, x):
        self.x_flatten = x.view(-1, 28*28)
        self.h = F.sigmoid(self.fc1(self.x_flatten))
        self.data_rho = self.h.mean(0)
        self.out = F.tanh(self.fc2(self.h))
        return self.out
    
    def decode(self, x):
        return F.tanh(self.fc2(x))
    
    def rho_loss(self, rho):
        """
        D_KL(P||Q) = sum(p*log(p/q)) = -sum(p*log(q/p)) = -p*log(q/p) - (1-p)log((1-q)/(1-p))
        """
        dkl = - torch.log(self.data_rho/rho) * rho - torch.log((1-self.data_rho)/(1-rho)) * (1-rho)
        return dkl.mean()
    
    def loss(self, x, target, **kwargs):
        return self._loss(x, target, **kwargs)

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.01)
sparse = True
rho = 0.05

# %%
def train(epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        
        rho_loss = model.rho_loss(rho)    
        loss = model.loss(output, data.view(-1, 784)) + rho_loss
        
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data[0]))
    else:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.data[0]))

# %%
def test(log=None):
    test_loss = 0
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        test_loss += model.loss(output, data.view(-1, 784), size_average=False).data[0] # sum up batch loss
    test_loss /= len(test_loader.dataset) * 784
    
    train_loss = 0
    for data, target in train_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        train_loss += model.loss(output, data.view(-1, 784), size_average=False).data[0] # sum up batch loss
    train_loss /= len(train_loader.dataset) * 784
    
    print('Average test/train loss: {:.4f}/{:.4f}\n'.format(test_loss, train_loss))
    
    log['test'].append(test_loss)
    log['train'].append(train_loss)

# %%
err_log = {'test': [], 'train': []}

# %%
for epoch in range(1, 11):
    train(epoch)
    test(err_log)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.512754
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 0.485223
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 0.497519
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 0.504897
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.454417
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 0.468589
# Train Epoch: 1 [59950/60000 (100%)]	Loss: 0.489132
# Average test/train loss: 0.4544/0.4497
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.492526
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.450083
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.481117
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.436841
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.486968
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.435538
# Train Epoch: 2 [59950/60000 (100%)]	Loss: 0.456980
# Average test/train loss: 0.4525/0.4473
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.459360
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.447373
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.471863
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.500106
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.467558
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.428037
# Train Epoch: 3 [59950/60000 (100%)]	Loss: 0.431955
# Average test/train loss: 0.4520/0.4470
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.435318
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.515694
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.406479
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.469821
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.452720
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.513838
# Train Epoch: 4 [59950/60000 (100%)]	Loss: 0.464082
# Average test/train loss: 0.4515/0.4467
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.451886
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.484578
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.481501
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.450244
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.483295
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.480813
# Train Epoch: 5 [59950/60000 (100%)]	Loss: 0.501587
# Average test/train loss: 0.4509/0.4461
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.477030
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 0.525773
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 0.509661
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 0.514826
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 0.490867
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 0.498822
# Train Epoch: 6 [59950/60000 (100%)]	Loss: 0.450282
# Average test/train loss: 0.4509/0.4459
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.499437
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 0.470347
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 0.506611
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 0.486069
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 0.468631
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 0.487359
# Train Epoch: 7 [59950/60000 (100%)]	Loss: 0.484567
# Average test/train loss: 0.4502/0.4450
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.416066
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 0.475905
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 0.470838
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 0.497114
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 0.473373
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 0.473580
# Train Epoch: 8 [59950/60000 (100%)]	Loss: 0.531200
# Average test/train loss: 0.4486/0.4437
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.455393
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 0.476883
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 0.485449
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 0.450895
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 0.462525
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 0.451533
# Train Epoch: 9 [59950/60000 (100%)]	Loss: 0.514801
# Average test/train loss: 0.4484/0.4431
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.444036
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 0.483307
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 0.480283
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 0.467932
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 0.482411
# Train Epoch: 10 [50000/60000 (83%)]	Loss: 0.496041
# Train Epoch: 10 [59950/60000 (100%)]	Loss: 0.462731
# Average test/train loss: 0.4481/0.4430

# %%
data, target = next(iter(train_loader))
data, target = Variable(data, volatile=True), Variable(target)

# %%
output = model(data)
to_plot = ((output.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(data.data.numpy(), (10, 5))
utils.plot_mnist(to_plot, (10, 5))

# %%
decoded = model.decode(Variable(torch.eye(64)))
dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(dec_to_plot, (8, 8))
