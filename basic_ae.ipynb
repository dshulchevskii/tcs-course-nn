# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import utils
# %matplotlib inline

# %%
train_loader = utils.loader(train=True, normalize=True)
test_loader = utils.loader(train=False, normalize=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 64)
        self.fc2 = nn.Linear(64, 28*28)
        self._loss = F.mse_loss
        
    def forward(self, x):
        self.x_flatten = x.view(-1, 28*28)
        self.h = F.sigmoid(self.fc1(self.x_flatten))
        self.out = F.tanh(self.fc2(self.h))
        return self.out
    
    def decode(self, x):
        return F.tanh(self.fc2(x))
    
    def loss(self, x, target, **kwargs):
        return self._loss(x, target, **kwargs)

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
def train(epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
            
        loss = model.loss(output, data.view(-1, 784))
        
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data[0]))
    else:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.data[0]))

# %%
def test(log=None):
    test_loss = 0
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        test_loss += model.loss(output, data.view(-1, 784), size_average=False).data[0] # sum up batch loss
    test_loss /= len(test_loader.dataset) * 784
    
    train_loss = 0
    for data, target in train_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        train_loss += model.loss(output, data.view(-1, 784), size_average=False).data[0] # sum up batch loss
    train_loss /= len(train_loader.dataset) * 784
    
    print('Average test/train loss: {:.4f}/{:.4f}\n'.format(test_loss, train_loss))
    
    log['test'].append(test_loss)
    log['train'].append(train_loss)

# %%
err_log = {'test': [], 'train': []}

# %%
for epoch in range(1, 11):
    train(epoch)
    test(err_log)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.070100
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 0.487801
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 0.478085
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 0.467170
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.454998
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 0.476290
# Train Epoch: 1 [59950/60000 (100%)]	Loss: 0.451845
# Average test/train loss: 0.4580/0.4532
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.478007
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.447191
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.464820
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.430708
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.462270
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.459371
# Train Epoch: 2 [59950/60000 (100%)]	Loss: 0.457291
# Average test/train loss: 0.4469/0.4421
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.453813
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.428152
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.447849
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.434445
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.465303
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.436229
# Train Epoch: 3 [59950/60000 (100%)]	Loss: 0.453231
# Average test/train loss: 0.4401/0.4353
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.439470
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.444215
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.427747
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.428233
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.468562
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.452976
# Train Epoch: 4 [59950/60000 (100%)]	Loss: 0.440196
# Average test/train loss: 0.4365/0.4318
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.441906
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.439070
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.411789
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.417936
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.447276
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.454147
# Train Epoch: 5 [59950/60000 (100%)]	Loss: 0.390623
# Average test/train loss: 0.4345/0.4297
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.423194
# Train Epoch: 6 [10000/60000 (17%)]	Loss: 0.376121
# Train Epoch: 6 [20000/60000 (33%)]	Loss: 0.430318
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 0.438839
# Train Epoch: 6 [40000/60000 (67%)]	Loss: 0.453165
# Train Epoch: 6 [50000/60000 (83%)]	Loss: 0.421545
# Train Epoch: 6 [59950/60000 (100%)]	Loss: 0.422734
# Average test/train loss: 0.4347/0.4297
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.452432
# Train Epoch: 7 [10000/60000 (17%)]	Loss: 0.428273
# Train Epoch: 7 [20000/60000 (33%)]	Loss: 0.450079
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 0.438074
# Train Epoch: 7 [40000/60000 (67%)]	Loss: 0.455347
# Train Epoch: 7 [50000/60000 (83%)]	Loss: 0.440781
# Train Epoch: 7 [59950/60000 (100%)]	Loss: 0.457153
# Average test/train loss: 0.4308/0.4259
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.476549
# Train Epoch: 8 [10000/60000 (17%)]	Loss: 0.436242
# Train Epoch: 8 [20000/60000 (33%)]	Loss: 0.419299
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 0.381499
# Train Epoch: 8 [40000/60000 (67%)]	Loss: 0.441083
# Train Epoch: 8 [50000/60000 (83%)]	Loss: 0.416114
# Train Epoch: 8 [59950/60000 (100%)]	Loss: 0.393290
# Average test/train loss: 0.4303/0.4254
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.460118
# Train Epoch: 9 [10000/60000 (17%)]	Loss: 0.443865
# Train Epoch: 9 [20000/60000 (33%)]	Loss: 0.418100
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 0.450066
# Train Epoch: 9 [40000/60000 (67%)]	Loss: 0.437431
# Train Epoch: 9 [50000/60000 (83%)]	Loss: 0.419115
# Train Epoch: 9 [59950/60000 (100%)]	Loss: 0.395842
# Average test/train loss: 0.4293/0.4243
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.418512
# Train Epoch: 10 [10000/60000 (17%)]	Loss: 0.415696
# Train Epoch: 10 [20000/60000 (33%)]	Loss: 0.417074
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 0.407464
# Train Epoch: 10 [40000/60000 (67%)]	Loss: 0.377217
# Train Epoch: 10 [50000/60000 (83%)]	Loss: 0.424877
# Train Epoch: 10 [59950/60000 (100%)]	Loss: 0.404815
# Average test/train loss: 0.4284/0.4235

# %%
data, target = next(iter(train_loader))
data, target = Variable(data, volatile=True), Variable(target)

# %%
output = model(data)
to_plot = ((output.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(data.data.numpy(), (10, 5))
utils.plot_mnist(to_plot, (10, 5))

# %%
decoded = model.decode(Variable(torch.eye(64)))
dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.numpy()
utils.plot_mnist(dec_to_plot, (8, 8))
